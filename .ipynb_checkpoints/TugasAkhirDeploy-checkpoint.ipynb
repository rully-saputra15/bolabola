# %%
#core package for data science
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# import package for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from flask_cors import CORS
from random import randint
#hide warnings so you can't find any warning
import warnings
warnings.simplefilter('ignore')

print("Done !!!")

from flask import Flask
from flask import request
app = Flask(__name__)
CORS(app)

@app.route("/")
def hello():
    data = pd.read_csv('EPL_Set.csv')
    data_2 = data.copy()
    encoder1 = LabelEncoder()
    encoder1.fit(data.iloc[:,6:7])
    win = encoder1.transform(data.iloc[:,6:7])
    win_team = pd.DataFrame(win,columns=['Win'])


    encoder1.fit(data_2.iloc[:,2:3])
    home = encoder1.transform(data_2.iloc[:,2:3])
    home_team = pd.DataFrame(home,columns=['Home'])
    le_name_mapping = dict(zip(encoder1.classes_, encoder1.transform(encoder1.classes_)))
    encoder1.fit(data_2.iloc[:,3:4])
    away = encoder1.transform(data.iloc[:,3:4])
    away_team = pd.DataFrame(away,columns=['Away'])


    data_encode = pd.concat([data,win_team,home_team,away_team], axis=1)

    X = data_encode[['FTHG','FTAG','HTHG','HTAG','Home','Away']]
    y = data_encode['Win']

    X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=45)

    log_clf = LogisticRegression()
    rnd_clf = RandomForestClassifier()
    svm_clf = SVC()
    voting_clf = VotingClassifier(
        estimators = [('lr', log_clf), ('rf', rnd_clf), ('svm', svm_clf)],
        voting = 'hard')

    voting_clf.fit(X_train, y_train)
    req = [[]]
    req[0].append(randint(0,7))
    req[0].append(randint(0,7))
    req[0].append(randint(0,7))
    req[0].append(randint(0,7))
    param = request.args.get('home')
    req[0].append(param)
    param = request.args.get('away')
    req[0].append(param)
    predik = voting_clf.predict(req)
    #predik1 = voting_clf.predict_proba(X_test)
    #skor = voting_clf.score(X_test, y_test)
    
    return str(predik)



if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9000, app)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#  * Running on http://localhost:9000/ (Press CTRL+C to quit)
# Done !!!
# [2019-11-13 20:25:44,635] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "E:\Anaconda\lib\site-packages\flask_cors\extension.py", line 161, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "E:\Anaconda\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "E:\Anaconda\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-18497e779e53>", line 76, in hello
#     predik = voting_clf.predict(req)
#   File "E:\Anaconda\lib\site-packages\sklearn\ensemble\voting_classifier.py", line 234, in predict
#     predictions = self._predict(X)
#   File "E:\Anaconda\lib\site-packages\sklearn\ensemble\voting_classifier.py", line 354, in _predict
#     return np.asarray([clf.predict(X) for clf in self.estimators_]).T
#   File "E:\Anaconda\lib\site-packages\sklearn\ensemble\voting_classifier.py", line 354, in <listcomp>
#     return np.asarray([clf.predict(X) for clf in self.estimators_]).T
#   File "E:\Anaconda\lib\site-packages\sklearn\linear_model\base.py", line 281, in predict
#     scores = self.decision_function(X)
#   File "E:\Anaconda\lib\site-packages\sklearn\linear_model\base.py", line 257, in decision_function
#     X = check_array(X, accept_sparse='csr')
#   File "E:\Anaconda\lib\site-packages\sklearn\utils\validation.py", line 573, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "E:\Anaconda\lib\site-packages\sklearn\utils\validation.py", line 56, in _assert_all_finite
#     raise ValueError(msg_err.format(type_err, X.dtype))
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
# 127.0.0.1 - - [13/Nov/2019 20:25:44] "GET /?home25&away=26 HTTP/1.1" 500 -

# %%
data = pd.read_csv('EPL_Set.csv')
data_2 = data.copy()
encoder1 = LabelEncoder()
encoder1.fit(data.iloc[:,6:7])
win = encoder1.transform(data.iloc[:,6:7])
win_team = pd.DataFrame(win,columns=['Win'])


encoder1.fit(data_2.iloc[:,2:3])
home = encoder1.transform(data_2.iloc[:,2:3])
home_team = pd.DataFrame(home,columns=['Home'])
le_name_mapping = dict(zip(encoder1.classes_, encoder1.transform(encoder1.classes_)))
encoder1.fit(data_2.iloc[:,3:4])
away = encoder1.transform(data.iloc[:,3:4])
away_team = pd.DataFrame(away,columns=['Away'])


data_encode = pd.concat([data,win_team,home_team,away_team], axis=1)

X = data_encode[['FTHG','FTAG','HTHG','HTAG','Home','Away']]
y = data_encode['Win']

X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=45)

log_clf = LogisticRegression()
rnd_clf = RandomForestClassifier()
svm_clf = SVC()
voting_clf = VotingClassifier(
    estimators = [('lr', log_clf), ('rf', rnd_clf), ('svm', svm_clf)],
    voting = 'hard')

voting_clf.fit(X_train, y_train)

predik = voting_clf.predict(X_test)
#predik1 = voting_clf.predict_proba(X_test)
predik

voting_clf.score(X_test, y_test)
